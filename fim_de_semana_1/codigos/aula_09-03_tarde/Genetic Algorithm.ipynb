# %%
from __future__ import print_function, division
import string
import numpy as np

# %%
class GeneticAlgorithm():
    """An implementation of a Genetic Algorithm which will try to produce the user
    specified target string.

    Parameters:
    -----------
    target_string: string
        The string which the GA should try to produce.
    population_size: int
        The number of individuals (possible solutions) in the population.
    mutation_rate: float
        The rate (or probability) of which the alleles (chars in this case) should be
        randomly changed.
    """
    def __init__(self, target_string, population_size, mutation_rate):
        self.target = target_string
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.letters = [" "] + list(string.ascii_letters)

    def _initialize(self):
        """ Initialize population with random strings """
        self.population = []
        for _ in range(self.population_size):
            # Select random letters as new individual
            individual = "".join(np.random.choice(self.letters, size=len(self.target)))
            self.population.append(individual)

    def _calculate_fitness(self):
        """ Calculates the fitness of each individual in the population """
        population_fitness = []
        for individual in self.population:
            # Calculate loss as the alphabetical distance between
            # the characters in the individual and the target string
            loss = 0
            for i in range(len(individual)):
                letter_i1 = self.letters.index(individual[i])
                letter_i2 = self.letters.index(self.target[i])
                loss += abs(letter_i1 - letter_i2)
            fitness = 1 / (loss + 1e-6)
            population_fitness.append(fitness)
        return population_fitness

    def _mutate(self, individual):
        """ Randomly change the individual's characters with probability
        self.mutation_rate """
        individual = list(individual)
        for j in range(len(individual)):
            # Make change with probability mutation_rate
            if np.random.random() < self.mutation_rate:
                individual[j] = np.random.choice(self.letters)
        # Return mutated individual as string
        return "".join(individual)

    def _crossover(self, parent1, parent2):
        """ Create children from parents by crossover """
        # Select random crossover point
        cross_i = np.random.randint(0, len(parent1))
        child1 = parent1[:cross_i] + parent2[cross_i:]
        child2 = parent2[:cross_i] + parent1[cross_i:]
        return child1, child2

    def run(self, iterations):
        # Initialize new population
        self._initialize()

        for epoch in range(iterations):
            population_fitness = self._calculate_fitness()

            fittest_individual = self.population[np.argmax(population_fitness)]
            highest_fitness = max(population_fitness)

            # If we have found individual which matches the target => Done
            if fittest_individual == self.target:
                break

            # Set the probability that the individual should be selected as a parent
            # proportionate to the individual's fitness.
            parent_probabilities = [fitness / sum(population_fitness) for fitness in population_fitness]

            # Determine the next generation
            new_population = []
            for i in np.arange(0, self.population_size, 2):
                # Select two parents randomly according to probabilities
                parent1, parent2 = np.random.choice(self.population, size=2, p=parent_probabilities, replace=False)
                # Perform crossover to produce offspring
                child1, child2 = self._crossover(parent1, parent2)
                # Save mutated offspring for next generation
                new_population += [self._mutate(child1), self._mutate(child2)]

            print ("[%d Closest Candidate: '%s', Fitness: %.2f]" % (epoch, fittest_individual, highest_fitness))
            self.population = new_population

        print ("[%d Answer: '%s']" % (epoch, fittest_individual))

# %%
ga = GeneticAlgorithm('Artificial Intelligence', 200, 0.02)

# %%
ga.run(1000)
# Out:
# [0 Closest Candidate: 'B SjibyvpngqjtryqdrhzOs', Fitness: 0.00]
# [1 Closest Candidate: 'WUejZdivpngqjtryqdrhzOs', Fitness: 0.00]
# [2 Closest Candidate: 'WUejZdivpngqjtryqdrnveB', Fitness: 0.00]
# [3 Closest Candidate: 'vfejZdivpngqjtryqdrnveB', Fitness: 0.00]
# [4 Closest Candidate: 'vfjfklseabgqjtryqdrnveB', Fitness: 0.01]
# [5 Closest Candidate: 'ZDpmmaanexgHjtryqdrnveB', Fitness: 0.01]
# [6 Closest Candidate: 'ZDpmmaanexgHjtryqdrnvub', Fitness: 0.01]
# [7 Closest Candidate: 'ZDpmmaanexgHjtryqdrnvub', Fitness: 0.01]
# [8 Closest Candidate: 'ZDpmmaanexgHvFomeRohvma', Fitness: 0.01]
# [9 Closest Candidate: 'uDpmmaanexgHjtryqdsDaaA', Fitness: 0.01]
# [10 Closest Candidate: 'uEDmmaanexgHjtryqdsDama', Fitness: 0.01]
# [11 Closest Candidate: 'tOjfkaanexgHjtjxfYohbma', Fitness: 0.01]
# [12 Closest Candidate: 'xxwibkClebrLdfesfOfezma', Fitness: 0.01]
# [13 Closest Candidate: 'xxwibkClebrLdfesfOfez  ', Fitness: 0.01]
# [14 Closest Candidate: 'ZDpmmhce bgMiMobeRo m a', Fitness: 0.01]
# [15 Closest Candidate: 'xxCtbkvaoxgHjtryqmgjmva', Fitness: 0.01]
# [16 Closest Candidate: 'tbummaaaoxgHjtryqmgjmeL', Fitness: 0.01]
# [17 Closest Candidate: 'ZxpmmhcneqgHcvjaucFesdl', Fitness: 0.01]
# [18 Closest Candidate: 'ZDpmmaanmsgLdtjxfJg mef', Fitness: 0.01]
# [19 Closest Candidate: 'ZDpmmhce bgMiP rbjbeFma', Fitness: 0.01]
# [20 Closest Candidate: 'xxpmmhcneqgCcvBsIdfemma', Fitness: 0.01]
# [21 Closest Candidate: 'yqmfkaanexbGwzryqdo Flh', Fitness: 0.01]
# [22 Closest Candidate: 'xxpmmhcneqgGitjxfOfhimh', Fitness: 0.01]
# [23 Closest Candidate: 'xxpmmAcnexgHjpryqmfazeb', Fitness: 0.01]
# [24 Closest Candidate: 'xxpmmhcejebGCtjmqvohmma', Fitness: 0.01]
# [25 Closest Candidate: 'xxwinhbm bgMiPomxjgjjia', Fitness: 0.01]
# [26 Closest Candidate: 'xxpmmhce bgGitjMqmgjjia', Fitness: 0.01]
# [27 Closest Candidate: 'xxwinhbm bgMiPbsldfemmE', Fitness: 0.01]
# [28 Closest Candidate: 'xxpimhceabgGitjMqmgjjia', Fitness: 0.01]
# [29 Closest Candidate: 'xxmfbicnexgHjpryqmfdFeb', Fitness: 0.01]
# [30 Closest Candidate: 'xxpimhceabgGigpiqgiemmf', Fitness: 0.01]
# [31 Closest Candidate: 'xxpimhceabgGigpiqgiemmf', Fitness: 0.01]
# [32 Closest Candidate: 'xxubbhce GgJjteAfjfbmlb', Fitness: 0.01]
# [33 Closest Candidate: 'xxubbhce GgJjteAfjfbmla', Fitness: 0.01]
# [34 Closest Candidate: 'KqDi dceaDbKcvjmlljcqjo', Fitness: 0.01]
# [35 Closest Candidate: 'KqDi dceaDbKcvjmlljcqlb', Fitness: 0.01]
# [36 Closest Candidate: 'xxpmmhce bbKcvjmlljcqlb', Fitness: 0.01]
# [37 Closest Candidate: 'xxpmmhce bbKcvjmlljcql ', Fitness: 0.01]
# [38 Closest Candidate: 'rxwibhca ibKjteAfjbbmlb', Fitness: 0.01]
# [39 Closest Candidate: 'ryubbhce xgJjteAfjfbmla', Fitness: 0.01]
# [40 Closest Candidate: 'xxpmmhce faJjteAfjfbmla', Fitness: 0.01]
# [41 Closest Candidate: 'xxuhmhce jbGippiljbegez', Fitness: 0.01]
# [42 Closest Candidate: 'Kqwibhfa ibKjtefedohme ', Fitness: 0.01]
# [43 Closest Candidate: 'xxninkcd iIGitemlljcmlb', Fitness: 0.01]
# [44 Closest Candidate: 'wswmjlce fbHgtlAlljcrma', Fitness: 0.01]
# [45 Closest Candidate: 'xxplmhce ibKjtemsbgazeb', Fitness: 0.01]
# [46 Closest Candidate: 'wswpmhce qgCitjmltjcmeb', Fitness: 0.01]
# [47 Closest Candidate: 'wswmjhce ibKjtemsbgazeb', Fitness: 0.01]
# [48 Closest Candidate: 'wswmjhce ibKjtemgjfbmla', Fitness: 0.02]
# [49 Closest Candidate: 'wswmjhce ibKjtemgjfbmjh', Fitness: 0.02]
# [50 Closest Candidate: 'zqpmjhcn ibKjteAqjfbmlp', Fitness: 0.01]
# [51 Closest Candidate: 'xxphmhce jbJjteffjfbmh ', Fitness: 0.02]
# [52 Closest Candidate: 'xxphmhce ibJjteffjfbmhh', Fitness: 0.02]
# [53 Closest Candidate: 'xxphmhce ibJjteffjfbmlb', Fitness: 0.01]
# [54 Closest Candidate: 'wxpmjkcd bgJjtjiljfdmla', Fitness: 0.01]
# [55 Closest Candidate: 'mquljhce ibKjtemblscmeb', Fitness: 0.01]
# [56 Closest Candidate: 'xxpmmhce jaJjteAgljemeb', Fitness: 0.01]
# [57 Closest Candidate: 'xxpmmhcd ibKjtemlljdzeb', Fitness: 0.01]
# [58 Closest Candidate: 'xBtimhce jaJjteAgljemeb', Fitness: 0.02]
# [59 Closest Candidate: 'wkti dce ibKjtemfmbbmda', Fitness: 0.02]
# [60 Closest Candidate: 'Eqommhce iaJjteAgljemee', Fitness: 0.02]
# [61 Closest Candidate: 'xqti dce obGiteAoljeoeb', Fitness: 0.02]
# [62 Closest Candidate: 'xqti dce obGiteAoljeoeb', Fitness: 0.02]
# [63 Closest Candidate: 'xqpmmhcn ibKbteilajameb', Fitness: 0.01]
# [64 Closest Candidate: 'xqti dce oaKjteAlljeoeh', Fitness: 0.02]
# [65 Closest Candidate: 'uxtinkce ibKjtemllbeueh', Fitness: 0.02]
# [66 Closest Candidate: 'mqtijhcneibKkoemljfbmlb', Fitness: 0.02]
# [67 Closest Candidate: 'wktinmce ibJjteilajemeh', Fitness: 0.02]
# [68 Closest Candidate: 'wztimhce ibJjtemljfbmlb', Fitness: 0.02]
# [69 Closest Candidate: 'Jrtinkce ibJjtemljfbmlb', Fitness: 0.02]
# [70 Closest Candidate: 'uxtiehce ibJjtemljfbmlb', Fitness: 0.02]
# [71 Closest Candidate: 'wrtinkcejibJjtemljjameb', Fitness: 0.02]
# [72 Closest Candidate: 'xxtinkcdeibJjtemljfbmeb', Fitness: 0.02]
# [73 Closest Candidate: 'wrtinkcd mgPjtemljfbmeb', Fitness: 0.02]
# [74 Closest Candidate: 'uxtiehcn ibKktemfjfameb', Fitness: 0.02]
# [75 Closest Candidate: 'xqwiehcn ibKktemfjfameb', Fitness: 0.02]
# [76 Closest Candidate: 'xqwiehcn ibKktemfjfemeb', Fitness: 0.02]
# [77 Closest Candidate: 'wrtm kcn ibKjtemljfemeb', Fitness: 0.02]
# [78 Closest Candidate: 'uptinhceeibJmtemljfemih', Fitness: 0.02]
# [79 Closest Candidate: 'uptinhceeibJmtemljfemib', Fitness: 0.02]
# [80 Closest Candidate: 'urtiemce ibKutemljfbpeb', Fitness: 0.02]
# [81 Closest Candidate: 'wrtibkceeibJmtemlljemeh', Fitness: 0.03]
# [82 Closest Candidate: 'wrtibkceeibJmtemlljemeb', Fitness: 0.03]
# [83 Closest Candidate: 'xrtiemcneibJjtemojfemeh', Fitness: 0.03]
# [84 Closest Candidate: 'wrtiemce ibKjtemljfameb', Fitness: 0.03]
# [85 Closest Candidate: 'wrtiemce ibKjtemljfemih', Fitness: 0.03]
# [86 Closest Candidate: 'wrtiemce ibKjtemljfemdh', Fitness: 0.03]
# [87 Closest Candidate: 'wrtiemce ibKjtemljfemdh', Fitness: 0.03]
# [88 Closest Candidate: 'xrtiemcd ibJmtemlljemeh', Fitness: 0.03]
# [89 Closest Candidate: 'wrtiemceeibKjtemljfemeb', Fitness: 0.03]
# [90 Closest Candidate: 'wqwinkch ibGmtemljfemeb', Fitness: 0.03]
# [91 Closest Candidate: 'urtiemce kbLmtemljfameh', Fitness: 0.03]
# [92 Closest Candidate: 'wrtiemcd qbKmtemljfbmeb', Fitness: 0.03]
# [93 Closest Candidate: 'vrtieccl kbJjtalljfemeb', Fitness: 0.03]
# [94 Closest Candidate: 'xrtiemce ibJptemljfemeb', Fitness: 0.03]
# [95 Closest Candidate: 'Artinkce ibJmtemljfemeb', Fitness: 0.03]
# [96 Closest Candidate: 'wptiemce kbJjtemljfbmeb', Fitness: 0.03]
# [97 Closest Candidate: 'wrtifhcn kbJjtallhfemeb', Fitness: 0.03]
# [98 Closest Candidate: 'wrtiemcd qbKmtemlhfbmeh', Fitness: 0.03]
# [99 Closest Candidate: 'wrtigmce ibKmtemlhfbmeb', Fitness: 0.03]
# [100 Closest Candidate: 'wrtigmce ibKmtemlhfemeb', Fitness: 0.03]
# [101 Closest Candidate: 'Artinkch qbGmtelljfemeb', Fitness: 0.03]
# [102 Closest Candidate: 'wrtiehcefibHmtemljfemeb', Fitness: 0.03]
# [103 Closest Candidate: 'wrtiekch qbGmtellhfbmeb', Fitness: 0.03]
# [104 Closest Candidate: 'wrtigmce ibKmtellhfgmeb', Fitness: 0.03]
# [105 Closest Candidate: 'Artieicd ibLmtemljfbmeh', Fitness: 0.04]
# [106 Closest Candidate: 'wrtiekch ibJmtelljfbmeb', Fitness: 0.04]
# [107 Closest Candidate: 'wrtiekch ibJmtelljfbmeb', Fitness: 0.04]
# [108 Closest Candidate: 'Artiemch qbGmtellhfdmeb', Fitness: 0.04]
# [109 Closest Candidate: 'wrtiehce ibHmtemljfemeh', Fitness: 0.04]
# [110 Closest Candidate: 'ArtiemckeibGmtellhfdmeb', Fitness: 0.04]
# [111 Closest Candidate: 'Artiemck qbJmtemlhfdmeb', Fitness: 0.04]
# [112 Closest Candidate: 'Artiehce nbJmtemljfemhb', Fitness: 0.04]
# [113 Closest Candidate: 'Artiehce nbJmtemljfemeb', Fitness: 0.05]
# [114 Closest Candidate: 'Artiemck qbJmtemljfemeb', Fitness: 0.04]
# [115 Closest Candidate: 'Brtiehch ibJmtelljfameh', Fitness: 0.04]
# [116 Closest Candidate: 'wrtifhch qbGmtemljfemeb', Fitness: 0.04]
# [117 Closest Candidate: 'wrtiehch i Hmtelljgemeb', Fitness: 0.05]
# [118 Closest Candidate: 'Artiehch ibLmtemljfdmeb', Fitness: 0.04]
# [119 Closest Candidate: 'Artifhch qbJmtellhfdmeb', Fitness: 0.05]
# [120 Closest Candidate: 'Artifhch nbHmtelljfamei', Fitness: 0.05]
# [121 Closest Candidate: 'Artifhch nbHmtelljfemeb', Fitness: 0.06]
# [122 Closest Candidate: 'Artifhch nbHmtemljgemef', Fitness: 0.07]
# [123 Closest Candidate: 'Artifhch nbGmtelljgemef', Fitness: 0.07]
# [124 Closest Candidate: 'Artifhch nbGmtelljgemef', Fitness: 0.07]
# [125 Closest Candidate: 'Artifhch nbGmtelljgemef', Fitness: 0.07]
# [126 Closest Candidate: 'Artifhck ibHmtelljgemef', Fitness: 0.06]
# [127 Closest Candidate: 'Artifhch nbGmtelljgemff', Fitness: 0.06]
# [128 Closest Candidate: 'Artifhch ibHmtelljgemef', Fitness: 0.07]
# [129 Closest Candidate: 'Artifhch nbJmtemljgemef', Fitness: 0.07]
# [130 Closest Candidate: 'Artifhch ibJmtelljgemef', Fitness: 0.07]
# [131 Closest Candidate: 'Artifhch nbGmtelljfemef', Fitness: 0.06]
# [132 Closest Candidate: 'Artifhch nbJmtelljfemef', Fitness: 0.07]
# [133 Closest Candidate: 'Artiehch nbJmtemljgemef', Fitness: 0.06]
# [134 Closest Candidate: 'Artiehch nbJmtemljgemef', Fitness: 0.06]
# [135 Closest Candidate: 'Artifhch nbJmtelljfemef', Fitness: 0.07]
# [136 Closest Candidate: 'Artiehch nbJmtelljgemef', Fitness: 0.07]
# [137 Closest Candidate: 'Artiehch nbJmtelljgemef', Fitness: 0.07]
# [138 Closest Candidate: 'Artifhch ibJmtelljgemef', Fitness: 0.07]
# [139 Closest Candidate: 'Artifhch nbJmtelljfemef', Fitness: 0.07]
# [140 Closest Candidate: 'ArtifhchaibHmtelljgemef', Fitness: 0.07]
# [141 Closest Candidate: 'Artiehch n Gmtemljgemef', Fitness: 0.07]
# [142 Closest Candidate: 'Artifhch nbJmtelljgemeg', Fitness: 0.07]
# [143 Closest Candidate: 'Artifhch nbJmtelljgemeg', Fitness: 0.07]
# [144 Closest Candidate: 'Arthfhch n Gmtelljgemef', Fitness: 0.07]
# [145 Closest Candidate: 'Artifhch n Jmtemljgemef', Fitness: 0.08]
# [146 Closest Candidate: 'Artifhch n Jmtemljgemef', Fitness: 0.08]
# [147 Closest Candidate: 'Artifhch n Kmtelljgemef', Fitness: 0.08]
# [148 Closest Candidate: 'Artifhch n Jmtemljgemef', Fitness: 0.08]
# [149 Closest Candidate: 'Artifhch n Jmtemljgemef', Fitness: 0.08]
# [150 Closest Candidate: 'Artifhch n Jmtemljgemef', Fitness: 0.08]
# [151 Closest Candidate: 'Artifhch naJmtelljgemef', Fitness: 0.08]
# [152 Closest Candidate: 'Artifhch lbJmtelljgemef', Fitness: 0.08]
# [153 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [154 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [155 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [156 Closest Candidate: 'Artifhch n Jmtelljfemef', Fitness: 0.08]
# [157 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [158 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [159 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [160 Closest Candidate: 'Artifhch lbJmtemligemef', Fitness: 0.08]
# [161 Closest Candidate: 'Artifich n Jmtemligemef', Fitness: 0.09]
# [162 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [163 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [164 Closest Candidate: 'Artifhch n Jmtelljgemef', Fitness: 0.08]
# [165 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [166 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [167 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [168 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [169 Closest Candidate: 'Artifich m Jmtelljgemef', Fitness: 0.10]
# [170 Closest Candidate: 'Artifich m Jntelljfemef', Fitness: 0.10]
# [171 Closest Candidate: 'Artifich m Jntelljfemef', Fitness: 0.10]
# [172 Closest Candidate: 'Artifich m Jntelljfemef', Fitness: 0.10]
# [173 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [174 Closest Candidate: 'Artifich n Jmtelljgemef', Fitness: 0.09]
# [175 Closest Candidate: 'Artigich m Jntelljgemed', Fitness: 0.10]
# [176 Closest Candidate: 'Artifichan Jntelljfemef', Fitness: 0.10]
# [177 Closest Candidate: 'Artifhchan Jntelljgemdf', Fitness: 0.11]
# [178 Closest Candidate: 'Artifhch m Jntelljgemdf', Fitness: 0.11]
# [179 Closest Candidate: 'Artifhch m Jntelljgemdf', Fitness: 0.11]
# [180 Closest Candidate: 'Artifhch m Jntelljgemdf', Fitness: 0.11]
# [181 Closest Candidate: 'Artifich n Jntelljgemdf', Fitness: 0.11]
# [182 Closest Candidate: 'Artifhchan Jntelljgemdf', Fitness: 0.11]
# [183 Closest Candidate: 'Artifichan Jntelljgemdf', Fitness: 0.12]
# [184 Closest Candidate: 'Artifhchan Jntelljgemdd', Fitness: 0.11]
# [185 Closest Candidate: 'Artifhchan Jntelljgemdd', Fitness: 0.11]
# [186 Closest Candidate: 'Artifhch m Jntelljgemdf', Fitness: 0.11]
# [187 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [188 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [189 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [190 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [191 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [192 Closest Candidate: 'Artifich m Jntelljgeodf', Fitness: 0.12]
# [193 Closest Candidate: 'Artifich m Jntelljgeodf', Fitness: 0.12]
# [194 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [195 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [196 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [197 Closest Candidate: 'Artifich n Jntelljgendf', Fitness: 0.12]
# [198 Closest Candidate: 'Artifich n Jntelljgendf', Fitness: 0.12]
# [199 Closest Candidate: 'Artifichbn Jntelljgemde', Fitness: 0.12]
# [200 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [201 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [202 Closest Candidate: 'Artifich m Jntelljgemdd', Fitness: 0.12]
# [203 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [204 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [205 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [206 Closest Candidate: 'Artifich l Jntelljgemdf', Fitness: 0.14]
# [207 Closest Candidate: 'Artifich l Jntelljgemdf', Fitness: 0.14]
# [208 Closest Candidate: 'Artifich l Jntelljgemdf', Fitness: 0.14]
# [209 Closest Candidate: 'Artifich m Jntelljgemdf', Fitness: 0.12]
# [210 Closest Candidate: 'Artifich n Jntelljgendf', Fitness: 0.12]
# [211 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [212 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [213 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [214 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [215 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [216 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [217 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [218 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [219 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [220 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [221 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [222 Closest Candidate: 'Artifich m Jntelljgendf', Fitness: 0.14]
# [223 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [224 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [225 Closest Candidate: 'Artifich m Intelljgendf', Fitness: 0.17]
# [226 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [227 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [228 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [229 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [230 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [231 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [232 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [233 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [234 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [235 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [236 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [237 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [238 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [239 Closest Candidate: 'Artifich m Jntellhgencf', Fitness: 0.17]
# [240 Closest Candidate: 'Artifich l Jntelljgencf', Fitness: 0.20]
# [241 Closest Candidate: 'Artifich m Jntelligendf', Fitness: 0.17]
# [242 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [243 Closest Candidate: 'Artifich m Jntelljgencf', Fitness: 0.17]
# [244 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [245 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [246 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [247 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [248 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [249 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [250 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [251 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [252 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [253 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [254 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [255 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [256 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [257 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [258 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [259 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [260 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [261 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [262 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [263 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [264 Closest Candidate: 'Artifich m Jntelligencf', Fitness: 0.20]
# [265 Closest Candidate: 'Artifich m Hntelligencf', Fitness: 0.20]
# [266 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [267 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [268 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [269 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [270 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [271 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [272 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [273 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [274 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [275 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [276 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [277 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [278 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [279 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [280 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [281 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [282 Closest Candidate: 'Artificham Jntelligencf', Fitness: 0.25]
# [283 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [284 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [285 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [286 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [287 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [288 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [289 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [290 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [291 Closest Candidate: 'Artificiam Jntelligencf', Fitness: 0.33]
# [292 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [293 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [294 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [295 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [296 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [297 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [298 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [299 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [300 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [301 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [302 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [303 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [304 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [305 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [306 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [307 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [308 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [309 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [310 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [311 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [312 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [313 Closest Candidate: 'Artificiam Intelligencf', Fitness: 0.50]
# [314 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [315 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [316 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [317 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [318 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [319 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [320 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [321 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [322 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [323 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [324 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [325 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [326 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [327 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [328 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [329 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [330 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [331 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [332 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [333 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [334 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [335 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [336 Closest Candidate: 'Artifichal Intelligencf', Fitness: 0.50]
# [337 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [338 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [339 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [340 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [341 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [342 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [343 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [344 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [345 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [346 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [347 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [348 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [349 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [350 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [351 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [352 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [353 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [354 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [355 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [356 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [357 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [358 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [359 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [360 Closest Candidate: 'Artificjam Intelligencf', Fitness: 0.33]
# [361 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [362 Closest Candidate: 'Artificjam Intelligencf', Fitness: 0.33]
# [363 Closest Candidate: 'Artificiam Intelligencf', Fitness: 0.50]
# [364 Closest Candidate: 'Artificjam Intelligencf', Fitness: 0.33]
# [365 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [366 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [367 Closest Candidate: 'Artificjam Intelligencf', Fitness: 0.33]
# [368 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [369 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [370 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [371 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [372 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [373 Closest Candidate: 'Artificjam Intelligencf', Fitness: 0.33]
# [374 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [375 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [376 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [377 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [378 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [379 Closest Candidate: 'Artificham Intelligencf', Fitness: 0.33]
# [380 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [381 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [382 Closest Candidate: 'Artificjam Intelligence', Fitness: 0.50]
# [383 Closest Candidate: 'Artificjam Intelligence', Fitness: 0.50]
# [384 Closest Candidate: 'Artificjam Intelligence', Fitness: 0.50]
# [385 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [386 Closest Candidate: 'Artificjam Intelligence', Fitness: 0.50]
# [387 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [388 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [389 Closest Candidate: 'Artificham Intelligence', Fitness: 0.50]
# [390 Closest Candidate: 'Artificiam Intelligence', Fitness: 1.00]
# [391 Closest Candidate: 'Artificiam Intelligence', Fitness: 1.00]
# [392 Closest Candidate: 'Artificiam Intelligence', Fitness: 1.00]
# [393 Closest Candidate: 'Artificiam Intelligence', Fitness: 1.00]
# [394 Closest Candidate: 'Artificiam Intelligence', Fitness: 1.00]
# [395 Answer: 'Artificial Intelligence']
